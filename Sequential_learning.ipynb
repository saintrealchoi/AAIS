# %%
# !nvidia-smi
# Out:
# Thu Feb 18 06:05:03 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 410.104      Driver Version: 410.104      CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla V100-DGXS...  On   | 00000000:07:00.0 Off |                    0 |
# | N/A   43C    P0    39W / 300W |     12MiB / 32478MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-DGXS...  On   | 00000000:08:00.0 Off |                    0 |
# | N/A   43C    P0    54W / 300W |   3801MiB / 32478MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  Tesla V100-DGXS...  On   | 00000000:0E:00.0 Off |                    0 |
# | N/A   43C    P0    51W / 300W |    541MiB / 32478MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  Tesla V100-DGXS...  On   | 00000000:0F:00.0 Off |                    0 |
# | N/A   43C    P0    50W / 300W |   1559MiB / 32478MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Dataset 분할
#
# ---
#
# `Train` : `Test` = 0.75 : 0.25
#
# - test
#
# 0-19 = 100명<br>
# 20-49 = 75명<br>
# 50- = 51명<br>
#
# = 226 * 4 = 804개의 image
#
# - train
#
#
# 0-19 = 299명
#
# 20-49 = 225명
#
# 50- = 154명
#
# = 678 * 4 = 2712개의 image

# %%
import os
path_dir1 = '../sungjin/sequential/46/train/'
path_dir2 = '../sungjin/sequential/46/test/'

sub_directory = ['0/','20/','50/']

TRAIN_NUM = 0
TEST_NUM = 0

for subdir in sub_directory:
    tmp_list = os.listdir(path_dir1+subdir)
    TRAIN_NUM += len(tmp_list)
    
for subdir in sub_directory:
    tmp2_list = os.listdir(path_dir2+subdir)
    TEST_NUM += len(tmp2_list)

# %%
# the number of training data = 2812
print(TRAIN_NUM)
# Out:
# 739

# %%
# the number of test data = 804
print(TEST_NUM)
# Out:
# 73

# %%
import numpy as np

# preprocessing image

train_img = np.float32(np.zeros((TRAIN_NUM,224,224,3)))
train_label = np.uint8(np.zeros((TRAIN_NUM,)))

test_img = np.float32(np.zeros((TEST_NUM,224,224,3)))
test_label = np.uint8(np.zeros((TEST_NUM,)))

# %% [markdown]
# ## Make Label
#
# ---
#
# ImageDataGenerator는 directory별로 data augmentation
#
# --> 두가지 네트워크를 비교했을 때 둘다 prediction에서 문제가 생김
#
# 따라서, 라벨링을 통해 다시한번 실험중

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.resnet50 import preprocess_input

make_label = [0,1,2]

num = 0
idx = 0
for subdir in sub_directory:
    give_label = make_label[idx]
    for file in os.listdir(path_dir1+subdir):
        src_path = path_dir1 + subdir + file
        img = load_img(src_path, target_size = (224,224))

        x = img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        
        train_img[num, :, :, :] = x

        train_label[num] = give_label
        num = num + 1
    idx += 1

# %%
num = 0
idx = 0

for subdir in sub_directory:
    give_label = make_label[idx]
    for file in os.listdir(path_dir2+subdir):
        src_path = path_dir2 + subdir + file
        img = load_img(src_path, target_size = (224,224))

        x = img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        
        test_img[num, :, :, :] = x

        test_label[num] = give_label
        num = num + 1
    idx += 1

# %%
import keras

train_label = keras.utils.to_categorical(train_label,3)
test_label = keras.utils.to_categorical(test_label,3)

# %% [markdown]
# ## Data Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# create a data generator

datagen = ImageDataGenerator(
#         zoom_range = 0.2, # 경계선부근에 치아가 있는경우 치아정보 손실가능성 증가
        brightness_range = [0.7,1.3],
        rotation_range=45,  # randomly rotate images in the range (degrees, 0 to 180)
        horizontal_flip=True,  # randomly flip images left and right
        vertical_flip=True)  # randomly flip images upside down

# %% [markdown]
# ## Transfer Learning

# %%
# def recall(y_target, y_pred):
#     # clip(t, clip_value_min, clip_value_max) : clip_value_min~clip_value_max 이외 가장자리를 깎아 낸다
#     # round : 반올림한다
#     y_target_yn = K.round(K.clip(y_target, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정한다
#     y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정한다

#     # True Positive는 실제 값과 예측 값이 모두 1(Positive)인 경우이다
#     count_true_positive = K.sum(y_target_yn * y_pred_yn) 

#     # (True Positive + False Negative) = 실제 값이 1(Positive) 전체
#     count_true_positive_false_negative = K.sum(y_target_yn)

#     # Recall =  (True Positive) / (True Positive + False Negative)
#     # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
#     recall = count_true_positive / (count_true_positive_false_negative + K.epsilon())

#     # return a single tensor value
#     return recall


# def precision(y_target, y_pred):
#     # clip(t, clip_value_min, clip_value_max) : clip_value_min~clip_value_max 이외 가장자리를 깎아 낸다
#     # round : 반올림한다
#     y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정한다
#     y_target_yn = K.round(K.clip(y_target, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정한다

#     # True Positive는 실제 값과 예측 값이 모두 1(Positive)인 경우이다
#     count_true_positive = K.sum(y_target_yn * y_pred_yn) 

#     # (True Positive + False Positive) = 예측 값이 1(Positive) 전체
#     count_true_positive_false_positive = K.sum(y_pred_yn)

#     # Precision = (True Positive) / (True Positive + False Positive)
#     # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
#     precision = count_true_positive / (count_true_positive_false_positive + K.epsilon())

#     # return a single tensor value
#     return precision


# def f1score(y_target, y_pred):
#     _recall = recall(y_target, y_pred)
#     _precision = precision(y_target, y_pred)
#     # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
#     _f1score = ( 2 * _recall * _precision) / (_recall + _precision+ K.epsilon())
    
#     # return a single tensor value
#     return _f1score

# %%
import tensorflow as tf
from keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,AveragePooling2D,Flatten,Dropout,GlobalAveragePooling2D,BatchNormalization, LeakyReLU
from tensorflow import keras
from sklearn.metrics import recall_score 
from sklearn.metrics import precision_score 
from sklearn.metrics import f1_score 
from sklearn.preprocessing import label_binarize

with tf.device('/gpu:2'):
    base_model = keras.applications.ResNet152(
        include_top=False,
        weights="imagenet",
        input_shape=(224,224,3)
    )
    
    x = keras.layers.Flatten()(base_model.output)
    x = keras.layers.Dense(128, activation= 'relu')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Dropout(0.5)(x)
    
    predictions = keras.layers.Dense(3,activation = 'softmax')(x)

    model = keras.models.Model(inputs = base_model.input,outputs =predictions)

    model.compile(optimizer = keras.optimizers.Adam(lr = 0.00001),
                  loss = 'categorical_crossentropy',
                  metrics = ['accuracy',])
    
    history = model.fit(datagen.flow(train_img,train_label,batch_size=32),
                        validation_data=datagen.flow(test_img,test_label,batch_size =32),
                        batch_size = 32,
                        epochs=10)

#     model.save("afterDelete_GAP.h5")
# Out:
# Epoch 1/10
# 24/24 [==============================] - 14s 584ms/step - loss: 1.8968 - accuracy: 0.3640 - val_loss: 1.7556 - val_accuracy: 0.3836
# Epoch 2/10
# 24/24 [==============================] - 10s 409ms/step - loss: 1.4251 - accuracy: 0.5129 - val_loss: 1.4718 - val_accuracy: 0.4658
# Epoch 3/10
# 24/24 [==============================] - 10s 409ms/step - loss: 1.2723 - accuracy: 0.5629 - val_loss: 1.1452 - val_accuracy: 0.5616
# Epoch 4/10
# 24/24 [==============================] - 10s 409ms/step - loss: 1.2019 - accuracy: 0.6035 - val_loss: 1.2377 - val_accuracy: 0.5342
# Epoch 5/10
# 24/24 [==============================] - 10s 416ms/step - loss: 1.1695 - accuracy: 0.6089 - val_loss: 0.8508 - val_accuracy: 0.6849
# Epoch 6/10
# 24/24 [==============================] - 10s 413ms/step - loss: 1.0832 - accuracy: 0.6319 - val_loss: 0.8701 - val_accuracy: 0.6301
# Epoch 7/10
# 24/24 [==============================] - 10s 420ms/step - loss: 0.9662 - accuracy: 0.6428 - val_loss: 0.7109 - val_accuracy: 0.7260
# Epoch 8/10
# 24/24 [==============================] - 10s 408ms/step - loss: 1.0407 - accuracy: 0.6604 - val_loss: 0.9227 - val_accuracy: 0.6712
# Epoch 9/10
# 24/24 [==============================] - 10s 407ms/step - loss: 0.9442 - accuracy: 0.6752 - val_loss: 0.7167 - val_accuracy: 0.6712
# Epoch 10/10
# 24/24 [==============================] - 10s 415ms/step - loss: 0.8578 - accuracy: 0.6901 - val_loss: 0.8726 - val_accuracy: 0.6301

# %%
path_dir1 = '../sungjin/sequential/36/train/'
path_dir2 = '../sungjin/sequential/36/test/'

sub_directory = ['0/','20/','50/']

TRAIN_NUM = 0
TEST_NUM = 0

for subdir in sub_directory:
    tmp_list = os.listdir(path_dir1+subdir)
    TRAIN_NUM += len(tmp_list)
    
for subdir in sub_directory:
    tmp2_list = os.listdir(path_dir2+subdir)
    TEST_NUM += len(tmp2_list)

import numpy as np

# preprocessing image

train_img = np.float32(np.zeros((TRAIN_NUM,224,224,3)))
train_label = np.uint8(np.zeros((TRAIN_NUM,)))

test_img = np.float32(np.zeros((TEST_NUM,224,224,3)))
test_label = np.uint8(np.zeros((TEST_NUM,)))

make_label = [0,1,2]

num = 0
idx = 0
for subdir in sub_directory:
    give_label = make_label[idx]
    for file in os.listdir(path_dir1+subdir):
        src_path = path_dir1 + subdir + file
        img = load_img(src_path, target_size = (224,224))

        x = img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        
        train_img[num, :, :, :] = x

        train_label[num] = give_label
        num = num + 1
    idx += 1

num = 0
idx = 0

for subdir in sub_directory:
    give_label = make_label[idx]
    for file in os.listdir(path_dir2+subdir):
        src_path = path_dir2 + subdir + file
        img = load_img(src_path, target_size = (224,224))

        x = img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        
        test_img[num, :, :, :] = x

        test_label[num] = give_label
        num = num + 1
    idx += 1
    
train_label = keras.utils.to_categorical(train_label,3)
test_label = keras.utils.to_categorical(test_label,3)

# %%
with tf.device('/gpu:2'):
    history = model.fit(datagen.flow(train_img,train_label,batch_size=32),
                            validation_data=datagen.flow(test_img,test_label,batch_size =32),
                            batch_size = 32,
                            epochs=10)
# Out:
# Epoch 1/10
# 23/23 [==============================] - 10s 441ms/step - loss: 0.9572 - accuracy: 0.6801 - val_loss: 0.7438 - val_accuracy: 0.7195
# Epoch 2/10
# 23/23 [==============================] - 10s 417ms/step - loss: 0.9195 - accuracy: 0.6510 - val_loss: 0.9114 - val_accuracy: 0.6585
# Epoch 3/10
# 23/23 [==============================] - 10s 415ms/step - loss: 0.8909 - accuracy: 0.7064 - val_loss: 0.8178 - val_accuracy: 0.7195
# Epoch 4/10
# 23/23 [==============================] - 10s 417ms/step - loss: 0.8949 - accuracy: 0.6676 - val_loss: 0.5255 - val_accuracy: 0.8049
# Epoch 5/10
# 23/23 [==============================] - 10s 420ms/step - loss: 0.8440 - accuracy: 0.6925 - val_loss: 0.7194 - val_accuracy: 0.7195
# Epoch 6/10
# 23/23 [==============================] - 10s 419ms/step - loss: 0.8033 - accuracy: 0.7105 - val_loss: 0.5790 - val_accuracy: 0.8049
# Epoch 7/10
# 23/23 [==============================] - 10s 424ms/step - loss: 0.8123 - accuracy: 0.7188 - val_loss: 0.6839 - val_accuracy: 0.6951
# Epoch 8/10
# 23/23 [==============================] - 10s 416ms/step - loss: 0.8010 - accuracy: 0.7230 - val_loss: 0.6701 - val_accuracy: 0.7561
# Epoch 9/10
# 23/23 [==============================] - 10s 418ms/step - loss: 0.7779 - accuracy: 0.7410 - val_loss: 0.5123 - val_accuracy: 0.7317
# Epoch 10/10
# 23/23 [==============================] - 10s 422ms/step - loss: 0.7174 - accuracy: 0.7452 - val_loss: 0.5704 - val_accuracy: 0.8049

# %%
path_dir1 = '../sungjin/sequential/26/train/'
path_dir2 = '../sungjin/sequential/26/test/'

sub_directory = ['0/','20/','50/']

TRAIN_NUM = 0
TEST_NUM = 0

for subdir in sub_directory:
    tmp_list = os.listdir(path_dir1+subdir)
    TRAIN_NUM += len(tmp_list)
    
for subdir in sub_directory:
    tmp2_list = os.listdir(path_dir2+subdir)
    TEST_NUM += len(tmp2_list)

import numpy as np

# preprocessing image

train_img = np.float32(np.zeros((TRAIN_NUM,224,224,3)))
train_label = np.uint8(np.zeros((TRAIN_NUM,)))

test_img = np.float32(np.zeros((TEST_NUM,224,224,3)))
test_label = np.uint8(np.zeros((TEST_NUM,)))

make_label = [0,1,2]

num = 0
idx = 0
for subdir in sub_directory:
    give_label = make_label[idx]
    for file in os.listdir(path_dir1+subdir):
        src_path = path_dir1 + subdir + file
        img = load_img(src_path, target_size = (224,224))

        x = img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        
        train_img[num, :, :, :] = x

        train_label[num] = give_label
        num = num + 1
    idx += 1

num = 0
idx = 0

for subdir in sub_directory:
    give_label = make_label[idx]
    for file in os.listdir(path_dir2+subdir):
        src_path = path_dir2 + subdir + file
        img = load_img(src_path, target_size = (224,224))

        x = img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        
        test_img[num, :, :, :] = x

        test_label[num] = give_label
        num = num + 1
    idx += 1
    
train_label = keras.utils.to_categorical(train_label,3)
test_label = keras.utils.to_categorical(test_label,3)

# %%
with tf.device('/gpu:2'):
    history = model.fit(datagen.flow(train_img,train_label,batch_size=32),
                            validation_data=datagen.flow(test_img,test_label,batch_size =32),
                            batch_size = 32,
                            epochs=10)
# Out:
# Epoch 1/10
# 24/24 [==============================] - 10s 437ms/step - loss: 1.2156 - accuracy: 0.6086 - val_loss: 0.8419 - val_accuracy: 0.7024
# Epoch 2/10
# 24/24 [==============================] - 10s 430ms/step - loss: 0.9975 - accuracy: 0.6475 - val_loss: 0.8235 - val_accuracy: 0.7500
# Epoch 3/10
# 24/24 [==============================] - 10s 433ms/step - loss: 1.0046 - accuracy: 0.6555 - val_loss: 0.6141 - val_accuracy: 0.7262
# Epoch 4/10
# 24/24 [==============================] - 10s 423ms/step - loss: 0.9926 - accuracy: 0.6689 - val_loss: 0.6809 - val_accuracy: 0.7381
# Epoch 5/10
# 24/24 [==============================] - 10s 421ms/step - loss: 0.9466 - accuracy: 0.6850 - val_loss: 0.7282 - val_accuracy: 0.7619
# Epoch 6/10
# 24/24 [==============================] - 10s 413ms/step - loss: 0.8425 - accuracy: 0.6984 - val_loss: 0.6490 - val_accuracy: 0.7976
# Epoch 7/10
# 24/24 [==============================] - 10s 416ms/step - loss: 0.7700 - accuracy: 0.7212 - val_loss: 0.6812 - val_accuracy: 0.7500
# Epoch 8/10
# 24/24 [==============================] - 10s 416ms/step - loss: 0.7814 - accuracy: 0.7319 - val_loss: 0.7860 - val_accuracy: 0.7381
# Epoch 9/10
# 24/24 [==============================] - 10s 418ms/step - loss: 0.7794 - accuracy: 0.7386 - val_loss: 0.9632 - val_accuracy: 0.6667
# Epoch 10/10
# 24/24 [==============================] - 10s 425ms/step - loss: 0.7779 - accuracy: 0.7212 - val_loss: 0.8039 - val_accuracy: 0.7262

# %%
path_dir1 = '../sungjin/sequential/16/train/'
path_dir2 = '../sungjin/sequential/16/test/'

sub_directory = ['0/','20/','50/']

TRAIN_NUM = 0
TEST_NUM = 0

for subdir in sub_directory:
    tmp_list = os.listdir(path_dir1+subdir)
    TRAIN_NUM += len(tmp_list)
    
for subdir in sub_directory:
    tmp2_list = os.listdir(path_dir2+subdir)
    TEST_NUM += len(tmp2_list)

import numpy as np

# preprocessing image

train_img = np.float32(np.zeros((TRAIN_NUM,224,224,3)))
train_label = np.uint8(np.zeros((TRAIN_NUM,)))

test_img = np.float32(np.zeros((TEST_NUM,224,224,3)))
test_label = np.uint8(np.zeros((TEST_NUM,)))

make_label = [0,1,2]

num = 0
idx = 0
for subdir in sub_directory:
    give_label = make_label[idx]
    for file in os.listdir(path_dir1+subdir):
        src_path = path_dir1 + subdir + file
        img = load_img(src_path, target_size = (224,224))

        x = img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        
        train_img[num, :, :, :] = x

        train_label[num] = give_label
        num = num + 1
    idx += 1

num = 0
idx = 0

for subdir in sub_directory:
    give_label = make_label[idx]
    for file in os.listdir(path_dir2+subdir):
        src_path = path_dir2 + subdir + file
        img = load_img(src_path, target_size = (224,224))

        x = img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        
        test_img[num, :, :, :] = x

        test_label[num] = give_label
        num = num + 1
    idx += 1
    
train_label = keras.utils.to_categorical(train_label,3)
test_label = keras.utils.to_categorical(test_label,3)

# %%
with tf.device('/gpu:2'):
    history = model.fit(datagen.flow(train_img,train_label,batch_size=32),
                            validation_data=datagen.flow(test_img,test_label,batch_size =32),
                            batch_size = 32,
                            epochs=10)
# Out:
# Epoch 1/10
# 24/24 [==============================] - 10s 427ms/step - loss: 0.9725 - accuracy: 0.6804 - val_loss: 0.4824 - val_accuracy: 0.7945
# Epoch 2/10
# 24/24 [==============================] - 10s 418ms/step - loss: 0.8405 - accuracy: 0.7257 - val_loss: 0.7401 - val_accuracy: 0.7534
# Epoch 3/10
# 24/24 [==============================] - 10s 410ms/step - loss: 0.8373 - accuracy: 0.7097 - val_loss: 0.5821 - val_accuracy: 0.7671
# Epoch 4/10
# 24/24 [==============================] - 10s 414ms/step - loss: 0.8627 - accuracy: 0.7071 - val_loss: 0.6945 - val_accuracy: 0.7671
# Epoch 5/10
# 24/24 [==============================] - 10s 414ms/step - loss: 0.7622 - accuracy: 0.7190 - val_loss: 0.7384 - val_accuracy: 0.7808
# Epoch 6/10
# 24/24 [==============================] - 10s 417ms/step - loss: 0.7667 - accuracy: 0.7204 - val_loss: 0.6843 - val_accuracy: 0.7397
# Epoch 7/10
# 24/24 [==============================] - 10s 408ms/step - loss: 0.6787 - accuracy: 0.7550 - val_loss: 0.5310 - val_accuracy: 0.8082
# Epoch 8/10
# 24/24 [==============================] - 10s 411ms/step - loss: 0.7003 - accuracy: 0.7470 - val_loss: 0.5109 - val_accuracy: 0.8493
# Epoch 9/10
# 24/24 [==============================] - 10s 413ms/step - loss: 0.6968 - accuracy: 0.7443 - val_loss: 0.6985 - val_accuracy: 0.7123
# Epoch 10/10
# 24/24 [==============================] - 10s 413ms/step - loss: 0.7006 - accuracy: 0.7643 - val_loss: 0.6640 - val_accuracy: 0.7671

# %%
path_dir1 = '../sungjin/tooth5/train/'
path_dir2 = '../sungjin/tooth5/test/'

sub_directory = ['0/','20/','50/']

TRAIN_NUM = 0
TEST_NUM = 0

for subdir in sub_directory:
    tmp_list = os.listdir(path_dir1+subdir)
    TRAIN_NUM += len(tmp_list)
    
for subdir in sub_directory:
    tmp2_list = os.listdir(path_dir2+subdir)
    TEST_NUM += len(tmp2_list)

import numpy as np

# preprocessing image

train_img = np.float32(np.zeros((TRAIN_NUM,224,224,3)))
train_label = np.uint8(np.zeros((TRAIN_NUM,)))

test_img = np.float32(np.zeros((TEST_NUM,224,224,3)))
test_label = np.uint8(np.zeros((TEST_NUM,)))

make_label = [0,1,2]

num = 0
idx = 0
for subdir in sub_directory:
    give_label = make_label[idx]
    for file in os.listdir(path_dir1+subdir):
        src_path = path_dir1 + subdir + file
        img = load_img(src_path, target_size = (224,224))

        x = img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        
        train_img[num, :, :, :] = x

        train_label[num] = give_label
        num = num + 1
    idx += 1

num = 0
idx = 0

for subdir in sub_directory:
    give_label = make_label[idx]
    for file in os.listdir(path_dir2+subdir):
        src_path = path_dir2 + subdir + file
        img = load_img(src_path, target_size = (224,224))

        x = img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        
        test_img[num, :, :, :] = x

        test_label[num] = give_label
        num = num + 1
    idx += 1
    
train_label = keras.utils.to_categorical(train_label,3)
test_label = keras.utils.to_categorical(test_label,3)

# %%
with tf.device('/gpu:2'):
    history = model.fit(datagen.flow(train_img,train_label,batch_size=32),
                            validation_data=datagen.flow(test_img,test_label,batch_size =32),
                            batch_size = 32,
                            epochs=50)
# Out:
# Epoch 1/50
# 94/94 [==============================] - 40s 429ms/step - loss: 0.6577 - accuracy: 0.7598 - val_loss: 0.6765 - val_accuracy: 0.7341
# Epoch 2/50
# 94/94 [==============================] - 39s 419ms/step - loss: 0.6815 - accuracy: 0.7524 - val_loss: 0.6418 - val_accuracy: 0.7402
# Epoch 3/50
# 94/94 [==============================] - 40s 423ms/step - loss: 0.6560 - accuracy: 0.7568 - val_loss: 0.6972 - val_accuracy: 0.7402
# Epoch 4/50
# 94/94 [==============================] - 39s 417ms/step - loss: 0.5966 - accuracy: 0.7722 - val_loss: 0.6021 - val_accuracy: 0.7644
# Epoch 5/50
# 94/94 [==============================] - 39s 419ms/step - loss: 0.5774 - accuracy: 0.7815 - val_loss: 0.6112 - val_accuracy: 0.7674
# Epoch 6/50
# 94/94 [==============================] - 40s 422ms/step - loss: 0.5912 - accuracy: 0.7779 - val_loss: 0.6220 - val_accuracy: 0.7613
# Epoch 7/50
# 94/94 [==============================] - 39s 417ms/step - loss: 0.5397 - accuracy: 0.7929 - val_loss: 0.6374 - val_accuracy: 0.7402
# Epoch 8/50
# 94/94 [==============================] - 39s 419ms/step - loss: 0.5117 - accuracy: 0.8043 - val_loss: 0.6453 - val_accuracy: 0.7492
# Epoch 9/50
# 94/94 [==============================] - 39s 420ms/step - loss: 0.5303 - accuracy: 0.7919 - val_loss: 0.6739 - val_accuracy: 0.7462
# Epoch 10/50
# 94/94 [==============================] - 39s 416ms/step - loss: 0.5019 - accuracy: 0.8009 - val_loss: 0.6225 - val_accuracy: 0.7251
# Epoch 11/50
# 94/94 [==============================] - 39s 418ms/step - loss: 0.5005 - accuracy: 0.8070 - val_loss: 0.6370 - val_accuracy: 0.7583
# Epoch 12/50
# 94/94 [==============================] - 39s 419ms/step - loss: 0.4770 - accuracy: 0.8110 - val_loss: 0.5106 - val_accuracy: 0.7704
# Epoch 13/50
# 94/94 [==============================] - 39s 415ms/step - loss: 0.4609 - accuracy: 0.8180 - val_loss: 0.5820 - val_accuracy: 0.7402
# Epoch 14/50
# 94/94 [==============================] - 39s 416ms/step - loss: 0.4204 - accuracy: 0.8321 - val_loss: 0.5849 - val_accuracy: 0.7885
# Epoch 15/50
# 94/94 [==============================] - 39s 418ms/step - loss: 0.4459 - accuracy: 0.8244 - val_loss: 0.5706 - val_accuracy: 0.7492
# Epoch 16/50
# 94/94 [==============================] - 39s 419ms/step - loss: 0.4135 - accuracy: 0.8377 - val_loss: 0.6178 - val_accuracy: 0.7251
# Epoch 17/50
# 94/94 [==============================] - 40s 421ms/step - loss: 0.3845 - accuracy: 0.8441 - val_loss: 0.4980 - val_accuracy: 0.7976
# Epoch 18/50
# 94/94 [==============================] - 39s 418ms/step - loss: 0.4044 - accuracy: 0.8451 - val_loss: 0.5270 - val_accuracy: 0.7674
# Epoch 19/50
# 94/94 [==============================] - 39s 419ms/step - loss: 0.3737 - accuracy: 0.8464 - val_loss: 0.5191 - val_accuracy: 0.7885
# Epoch 20/50
# 94/94 [==============================] - 39s 416ms/step - loss: 0.3489 - accuracy: 0.8561 - val_loss: 0.5077 - val_accuracy: 0.8006
# Epoch 21/50
# 94/94 [==============================] - 39s 417ms/step - loss: 0.3423 - accuracy: 0.8632 - val_loss: 0.6301 - val_accuracy: 0.7281
# Epoch 22/50
# 94/94 [==============================] - 39s 419ms/step - loss: 0.3547 - accuracy: 0.8625 - val_loss: 0.6031 - val_accuracy: 0.7583
# Epoch 23/50
# 94/94 [==============================] - 39s 417ms/step - loss: 0.3468 - accuracy: 0.8608 - val_loss: 0.5931 - val_accuracy: 0.7734
# Epoch 24/50
# 94/94 [==============================] - 39s 418ms/step - loss: 0.3207 - accuracy: 0.8745 - val_loss: 0.5404 - val_accuracy: 0.7704
# Epoch 25/50
# 94/94 [==============================] - 39s 416ms/step - loss: 0.3574 - accuracy: 0.8652 - val_loss: 0.5505 - val_accuracy: 0.7855
# Epoch 26/50
# 94/94 [==============================] - 39s 419ms/step - loss: 0.3008 - accuracy: 0.8769 - val_loss: 0.4699 - val_accuracy: 0.8097
# Epoch 27/50
# 94/94 [==============================] - 39s 418ms/step - loss: 0.3154 - accuracy: 0.8709 - val_loss: 0.5577 - val_accuracy: 0.7613
# Epoch 28/50
# 94/94 [==============================] - 39s 417ms/step - loss: 0.3054 - accuracy: 0.8749 - val_loss: 0.4422 - val_accuracy: 0.8006
# Epoch 29/50
# 94/94 [==============================] - 39s 418ms/step - loss: 0.2941 - accuracy: 0.8806 - val_loss: 0.5710 - val_accuracy: 0.7613
# Epoch 30/50
# 94/94 [==============================] - 40s 420ms/step - loss: 0.2909 - accuracy: 0.8839 - val_loss: 0.5842 - val_accuracy: 0.7553
# Epoch 31/50
# 94/94 [==============================] - 39s 416ms/step - loss: 0.2767 - accuracy: 0.8883 - val_loss: 0.5299 - val_accuracy: 0.7734
# Epoch 32/50
# 94/94 [==============================] - 40s 421ms/step - loss: 0.2677 - accuracy: 0.8893 - val_loss: 0.4952 - val_accuracy: 0.7674
# Epoch 33/50
# 94/94 [==============================] - 39s 415ms/step - loss: 0.2885 - accuracy: 0.8866 - val_loss: 0.6182 - val_accuracy: 0.7644
# Epoch 34/50
# 94/94 [==============================] - 39s 415ms/step - loss: 0.2627 - accuracy: 0.8983 - val_loss: 0.5759 - val_accuracy: 0.7764
# Epoch 35/50
# 94/94 [==============================] - 39s 415ms/step - loss: 0.2298 - accuracy: 0.9060 - val_loss: 0.6730 - val_accuracy: 0.7492
# Epoch 36/50
# 94/94 [==============================] - 40s 422ms/step - loss: 0.2422 - accuracy: 0.9073 - val_loss: 0.6618 - val_accuracy: 0.7825
# Epoch 37/50
# 94/94 [==============================] - 40s 421ms/step - loss: 0.2434 - accuracy: 0.9063 - val_loss: 0.7320 - val_accuracy: 0.7311
# Epoch 38/50
# 94/94 [==============================] - 39s 416ms/step - loss: 0.2141 - accuracy: 0.9160 - val_loss: 0.7752 - val_accuracy: 0.7492
# Epoch 39/50
# 94/94 [==============================] - 39s 419ms/step - loss: 0.2093 - accuracy: 0.9200 - val_loss: 0.5922 - val_accuracy: 0.7764
# Epoch 40/50
# 94/94 [==============================] - 40s 422ms/step - loss: 0.2196 - accuracy: 0.9113 - val_loss: 0.5517 - val_accuracy: 0.7764
# Epoch 41/50
# 94/94 [==============================] - 39s 417ms/step - loss: 0.1867 - accuracy: 0.9281 - val_loss: 0.6366 - val_accuracy: 0.7613
# Epoch 42/50
# 94/94 [==============================] - 39s 417ms/step - loss: 0.2058 - accuracy: 0.9227 - val_loss: 0.7027 - val_accuracy: 0.7795
# Epoch 43/50
# 94/94 [==============================] - 39s 420ms/step - loss: 0.1816 - accuracy: 0.9277 - val_loss: 0.5787 - val_accuracy: 0.7825
# Epoch 44/50
# 94/94 [==============================] - 39s 418ms/step - loss: 0.2169 - accuracy: 0.9184 - val_loss: 0.5054 - val_accuracy: 0.8097
# Epoch 45/50
# 94/94 [==============================] - 39s 416ms/step - loss: 0.1940 - accuracy: 0.9204 - val_loss: 0.5661 - val_accuracy: 0.7885
# Epoch 46/50
# 94/94 [==============================] - 39s 419ms/step - loss: 0.1551 - accuracy: 0.9408 - val_loss: 0.7068 - val_accuracy: 0.7553
# Epoch 47/50
# 94/94 [==============================] - 39s 420ms/step - loss: 0.1747 - accuracy: 0.9381 - val_loss: 0.8313 - val_accuracy: 0.7492
# Epoch 48/50
# 94/94 [==============================] - 39s 416ms/step - loss: 0.1551 - accuracy: 0.9428 - val_loss: 0.6657 - val_accuracy: 0.7976
# Epoch 49/50
# 94/94 [==============================] - 39s 418ms/step - loss: 0.1633 - accuracy: 0.9408 - val_loss: 0.6787 - val_accuracy: 0.7734
# Epoch 50/50
# 94/94 [==============================] - 39s 417ms/step - loss: 0.1656 - accuracy: 0.9408 - val_loss: 0.5909 - val_accuracy: 0.8066

# %%
# # base_model.trainable = False

# %%
import numpy as np
import matplotlib.pyplot as plt

y_vloss = history.history['val_loss']
y_loss = history.history['loss']

x_len = np.arange(len(y_loss))


plt.plot(x_len, y_vloss, marker='.', c='red', label="Validation-set Loss")
plt.plot(x_len, y_loss, marker='.', c='blue', label="Train-set Loss")

plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-aa0f56e7cc4f> in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 y_vloss = history.history['val_loss']
#       5 y_loss = history.history['loss']
#       6
#
# NameError: name 'history' is not defined

# %%
y_vacc = history.history['val_accuracy']
y_acc = history.history['accuracy']

x_len = np.arange(len(y_acc))

plt.plot(x_len, y_vacc, marker='.', c='red')
plt.plot(x_len, y_acc, marker='.', c='blue')

plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %% [markdown]
# ## Predict

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from tensorflow.keras.preprocessing import image as image_utils
from tensorflow.keras.applications.imagenet_utils import preprocess_input

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
import os

path = '../sungjin/tooth5/test/'
subdir = ['0/','20/','50/']
num = 0
idx = 0
count = 0

for sub in subdir:
    num = 0
    count = 0
    print("                                            "+subdir[idx])
    print("--------------------------------------------------------------------------------------")
    for file in os.listdir(path+sub):
        src_path = path + sub+file
        img = load_img(src_path, target_size = (224,224))

        x = img_to_array(img)
        x = x.reshape(1,224,224,3)
        x = preprocess_input(x)
        preds = model.predict(x)
        if np.argmax(preds)==idx:
            count+=1
            print("T", end = ' ')
        else :
            print("F", end = ' ')
        num = num + 1
        
        if num == 50:
            print(" ")
            print("총 50개 중에"+repr(count)+"개 맞혔습니다.")
            print(repr((count/50)*100)+"% prediction")
            print()
            break
            
    idx +=1
    print(" ")
# Out:
#                                             0/
# --------------------------------------------------------------------------------------
# T T F T T T T T F T T F T T T T T T T T F T T T T T T F T F F T T T T T F T T F F T F T F T F F F T
# 총 50개 중에35개 맞혔습니다.
# 70.0% prediction
#
#
#                                             20/
# --------------------------------------------------------------------------------------
# T T T F T T T F T F T T T T T T T F T T T T T T T T T T T F T F T T T T T T T F T T T T T F F F F F
# 총 50개 중에38개 맞혔습니다.
# 76.0% prediction
#
#
#                                             50/
# --------------------------------------------------------------------------------------
# T F F T F T T T T T T T T F F T T T T T T F T F T T F F T T T T F T F F T T F F F F T T F T T F T T
# 총 50개 중에32개 맞혔습니다.
# 64.0% prediction

# %% [markdown]
# ## Grad-CAM

# %%
from keras import layers
from keras import models
from keras import backend as K
import cv2

import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from tensorflow.keras.preprocessing import image as image_utils
from tensorflow.keras.applications.imagenet_utils import preprocess_input

# %%
def gradCAM(image):
    conv_layer = model.get_layer("conv5_block3_3_conv")
    heatmap_model = models.Model([model.inputs],[conv_layer.output,model.output])

    with tf.GradientTape() as gtape:
        conv_output, predictions = heatmap_model(image) # y^c, c
        loss = predictions[:, np.argmax(predictions[0])] # probability
        grads = gtape.gradient(loss, conv_output) # partial-derivative
        pooled_grads = K.mean(grads, axis=(0, 1, 2)) # a_k^c , weight

    heatmap = tf.reduce_mean(tf.multiply(pooled_grads, conv_output), axis=-1) # summation weight * filter
    heatmap = np.maximum(heatmap, 0) # ReLu
    max_heat = np.max(heatmap) # normalization    


    if max_heat == 0:
        max_heat = 1e-10
    heatmap /= max_heat
    
    image = image[0]
    image = cv2.resize(image, (112,153))

    hm = heatmap[0]
    hm = cv2.resize(hm, (image.shape[1],image.shape[0]))
    hm = np.uint8(255*hm)
    hm = cv2.applyColorMap(hm,cv2.COLORMAP_JET)

    cvt_heatmap = cv2.cvtColor(hm, cv2.COLOR_BGR2RGB)

    superimposed_img = cvt_heatmap * 0.3 + image

    superimposed_img[superimposed_img > 255] = 255
    superimposed_img = superimposed_img.astype('uint8')


    return superimposed_img,np.argmax(predictions[0])

# %%
import matplotlib.pyplot as plt
# 첫 번째 차원을 추가하여 확장

img_path = '../sungjin/tooth5/test/0/20323665 한하은 26.png' # 제대로됨
# img_path = '../sungjin/tooth5/test/20/20328047 이지수 16.png' # 제대로됨
# img_path = '../sungjin/tooth5/test/20/20103381 이혜정 26.png' # 1개 오류
# img_path = '../sungjin/tooth5/test/20/20108982 서윤경 16.png' #w
# img_path = '../sungjin/tooth5/test/20/20111069 한은영 16.png'
# img_path = '../sungjin/tooth5/test/20/20212220 이영원 16.png'
# img_path = '../sungjin/tooth5/test/20/20272160 김영석 16.png'
# img_path = '../sungjin/tooth3/test/under50/20683982 기선미 16.png'

image = image_utils.load_img(img_path)
image = image_utils.img_to_array(image)
image = np.expand_dims(x,axis = 0)
x = preprocess_input(x)

datagen.fit(train_img)
datagen.fit(test_img)


it = datagen.flow(x, batch_size=32)
fig = plt.figure(figsize = (10,10))

plt.subplot(3,3,1)
a,b = gradCAM(x)
plt.imshow(a)
plt.title(np.argmax(model.predict(x)))

# layer which calculate `score class`


# 9개 이미지 생성
for i in range(8):
    plt.subplot(3, 3, i+2)
    batch = it.next()
    
#     image = batch[0].astype('uint8')
    image,predict = gradCAM(batch)
    plt.imshow(image)
    plt.title(predict)

# show the figure
plt.show()

# %% [markdown]
# ## ROC-AUC

# %%
# labels = [0, 1, 2]

# ytest  = [0,1,2,3,2,2,1,0,1]

# # Binarize ytest with shape (n_samples, n_classes)
# ytest = label_binarize(ytest, classes=labels)

# ypreds = [1,2,1,3,2,2,0,1,1]

# # Binarize ypreds with shape (n_samples, n_classes)
# ypreds = label_binarize(ypreds, classes=labels)


# roc_auc_score(ytest, ypreds,average='macro',multi_class='ovo')

# %%
import pandas as pd
from sklearn.metrics import roc_auc_score,roc_curve,accuracy_score,recall_score
p = model.predict(test_img, verbose=True)
pre = pd.DataFrame(p)
# Out:
# 11/11 [==============================] - 1s 86ms/step

# %%
pre["predict"] = pre.idxmax(axis=1)
pre["predict"] = (pre["predict"]==0).apply(int)
label = np.argmax(test_label,axis = 1).reshape(-1,1)
pre["label"] = label
pre["label"] = (pre["label"]==0).apply(int)

# %%
recall_score(pre["label"],pre["predict"])
# Out:
# 0.7295597484276729

# %%
roc_auc_score(pre["label"],pre["predict"])
# Out:
# 0.8269891765394177

# %%
p = model.predict(test_img, verbose=True)
pre = pd.DataFrame(p)

pre["predict"] = pre.idxmax(axis=1)
pre["predict"] = (pre["predict"]==1).apply(int)
label = np.argmax(test_label,axis = 1).reshape(-1,1)
pre["label"] = label
pre["label"] = (pre["label"]==1).apply(int)

recall_score(pre["label"],pre["predict"])
# Out:
# 11/11 [==============================] - 1s 66ms/step
# 0.7130434782608696

# %%
roc_auc_score(pre["label"],pre["predict"])
# Out:
# 0.7199476650563607

# %%
p = model.predict(test_img, verbose=True)
pre = pd.DataFrame(p)

pre["predict"] = pre.idxmax(axis=1)
pre["predict"] = (pre["predict"]==1).apply(int)
label = np.argmax(test_label,axis = 1).reshape(-1,1)
pre["label"] = label
pre["label"] = (pre["label"]==1).apply(int)

recall_score(pre["label"],pre["predict"])
# Out:
# 11/11 [==============================] - 1s 66ms/step
# 0.7130434782608696

# %%
roc_auc_score(pre["label"],pre["predict"])
# Out:
# 0.7199476650563607

# %%
import IPython
app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}
